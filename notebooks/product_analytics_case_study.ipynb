# %% [markdown]
# # Product Analytics Case Study\n\nThis notebook walks through a portfolio-grade product analytics workflow:\n- funnel conversion\n- cohort retention\n- A/B testing\n- KPI synthesis\n

# %%
import pandas as pd\nfrom src.utils import load_events\nfrom src.funnel import build_funnel_report\nfrom src.retention import build_retention_report\nfrom src.ab_testing import build_experiment_report\n\nevents = load_events('data/raw/events.csv')\nevents.head()

# %%
funnel_report = build_funnel_report(events)\nfunnel_report.head(10)

# %%
retention_report = build_retention_report(events)\nretention_report.head(12)

# %%
experiment_report = build_experiment_report(events)\nexperiment_report

# %% [markdown]
# ## Suggested recruiter narrative\n\n1. Start with funnel drop-off and identify the weakest segment.\n2. Show whether retention is improving or worsening across cohorts.\n3. Close with the experiment recommendation and expected lift.\n
